# %% [markdown]
# # MELODI Presto API Example Usage

# %%
import json
import pandas as pd
import requests

# %% [markdown]
# ## Configure parameters

# %%
API_URL = "https://melodi-presto.mrcieu.ac.uk/api/"

requests.get(f"{API_URL}/status").json()
# Out:
# True

# %% [markdown]
# ## Create functions for the endpoints
#
# Each of the endoints can be wrapped up in a function:

# %%
#enrich
def enrich(q):
    endpoint = "/enrich/"
    url = f"{API_URL}{endpoint}"
    params = {
        "query": q,
    }
    response = requests.post(url, data=json.dumps(params))
    try:
        res = response.json()
        enrich_df = (
                pd.json_normalize(res)
        )
        return enrich_df
    except:
        print('No data')
        return []
    
#overlap
def overlap(q1,q2):
    endpoint = "/overlap/"
    url = f"{API_URL}{endpoint}"
    params = {
        "x": q1,
        "y": q2,
    }
    response = requests.post(url, data=json.dumps(params))
    res = response.json()
    if 'data' in res:
        overlap_df = (    
            pd.json_normalize(res['data'])
        )
    else:
        overlap_df=pd.DataFrame()
    return overlap_df

def sentence(q):
    endpoint = "/sentence/"
    url = f"{API_URL}{endpoint}"
    params = {
        "pmid": pmid,
    }
    response = requests.post(url, data=json.dumps(params))
    res = response.json()
    pub_df = (
        pd.json_normalize(res['data'])
    )
    return pub_df

# %% [markdown]
# #### Some extra functions
#
# It may also be useful to filter the overlap records to exclude any results derived from the same publication

# %%
def pub_check(row):
    px = set(row['pmids_x'].split(' '))
    py = set(row['pmids_y'].split(' '))
    check=[]
    if len(px.intersection(py)) > 0: 
        return False
    else:
        return True

# %% [markdown]
# ### Get enriched SemMedDB objects for a given search term
#
# Starting from a PubMed search, return all SemMedDB subject-predicate-object triples, their enrcichment metrics and publication information

# %%
# query_term='chronic kidney disease'
query_term='atopic dermatitis'
enrich_df = enrich(query_term)
enrich_df
# Out:
#                   query                                             triple  \
# 0     atopic_dermatitis  Topical form corticosteroids:TREATS:Dermatitis...
# 1     atopic_dermatitis                dupilumab:TREATS:Dermatitis, Atopic
# 2     atopic_dermatitis             Cyclosporine:TREATS:Dermatitis, Atopic
# 3     atopic_dermatitis            IGHE:ASSOCIATED_WITH:Dermatitis, Atopic
# 4     atopic_dermatitis               Tacrolimus:TREATS:Dermatitis, Atopic
# ...                 ...                                                ...
# 2860  atopic_dermatitis        interleukin-22:ASSOCIATED_WITH:Nasal Polyps
# 2861  atopic_dermatitis  IL17A protein, human|IL17A:STIMULATES:CCL20 ge...
# 2862  atopic_dermatitis           Adipokines:CAUSES:Dermatologic disorders
# 2863  atopic_dermatitis  High Density Lipoproteins:ASSOCIATED_WITH:Derm...
# 2864  atopic_dermatitis  Sleep Apnea, Obstructive:COEXISTS_WITH:Dermato...
#
#                       subject_name subject_type     subject_id  \
# 0     Topical form corticosteroids         phsu       C0304604
# 1                        dupilumab         phsu       C3660996
# 2                     Cyclosporine         phsu       C0010592
# 3                             IGHE         gngm           3497
# 4                       Tacrolimus         phsu       C0085149
# ...                            ...          ...            ...
# 2860                interleukin-22         aapp       C0961814
# 2861    IL17A protein, human|IL17A         aapp  C1701790|3605
# 2862                    Adipokines         aapp       C1955907
# 2863     High Density Lipoproteins         aapp       C0023821
# 2864      Sleep Apnea, Obstructive         dsyn       C0520679
#
#             predicate             object_name object_type      object_id  \
# 0              TREATS      Dermatitis, Atopic        dsyn       C0011615
# 1              TREATS      Dermatitis, Atopic        dsyn       C0011615
# 2              TREATS      Dermatitis, Atopic        dsyn       C0011615
# 3     ASSOCIATED_WITH      Dermatitis, Atopic        dsyn       C0011615
# 4              TREATS      Dermatitis, Atopic        dsyn       C0011615
# ...               ...                     ...         ...            ...
# 2860  ASSOCIATED_WITH            Nasal Polyps        dsyn       C0027430
# 2861       STIMULATES        CCL20 gene|CCL20        gngm  C1366524|6364
# 2862           CAUSES  Dermatologic disorders        dsyn       C0037274
# 2863  ASSOCIATED_WITH  Dermatologic disorders        dsyn       C0037274
# 2864    COEXISTS_WITH  Dermatologic disorders        dsyn       C0037274
#
#      localCount localTotal globalCount globalTotal                odds  \
# 0           208      24841         210     8040465    323.293189739664
# 1           203      24841         210     8040465  315.45768731228185
# 2           191      24841         194     8040465   321.1333433010602
# 3           169      24841         173     8040465   318.3523546853797
# 4           122      24841         123     8040465   322.6252423582531
# ...         ...        ...         ...         ...                 ...
# 2860          2      24841           2     8040465   323.7031684045251
# 2861          2      24841           5     8040465  129.48121905068643
# 2862          2      24841           2     8040465   323.7031684045251
# 2863          2      24841           2     8040465   323.7031684045251
# 2864          2      24841           2     8040465   323.7031684045251
#
#                         pval  \
# 0                        0.0
# 1                        0.0
# 2                        0.0
# 3                     5e-324
# 4     5.885335769260758e-235
# ...                      ...
# 2860   5.668202001922647e-05
# 2861   0.0001971685569559836
# 2862   5.668202001922647e-05
# 2863   5.668202001922647e-05
# 2864   5.668202001922647e-05
#
#                                                   pmids
# 0     33837558 33511682 33314940 33298043 33170543 3...
# 1     33894325 33889195 33866905 33851078 33844308 3...
# 2     31640767 31566785 31291386 31245879 31099402 3...
# 3     33645549 32068307 31218782 30937128 29528575 2...
# 4     31483891 30877873 30851973 30742708 30478741 2...
# ...                                                 ...
# 2860                                           32935490
# 2861                                  33509657 33253386
# 2862                                           33260746
# 2863                                           33271807
# 2864                                           33767945
#
# [2865 rows x 16 columns]

# %%
enrich_df.shape
# Out:
# (2865, 16)

# %%
print(enrich_df.triple.head(2))
# Out:
# 0    Topical form corticosteroids:TREATS:Dermatitis...
# 1                  dupilumab:TREATS:Dermatitis, Atopic
# Name: triple, dtype: object

# %% [markdown]
# ### Overlapping terms
#
# We can provide two lists of query terms and identify overlapping data

# %%
# x=['MLH1','MSH2','MLH3','MSH6','PMS1','PMS2','APC']
x = ['korean red ginseng']
# y=['Hereditary non-polyposis colon cancer']
y = ['dermatitis']

overlap_df = overlap(x,y)
print(overlap_df.shape)

#remove records found in the same publication
pub_filter=overlap_df.apply(pub_check,axis=1)
pub_removed = overlap_df.shape[0]-pub_filter.sum()
print(pub_removed,'records were found in the same publication')
overlap_df=overlap_df[pub_filter]
print(overlap_df.shape)
overlap_df
# Out:
# (568, 32)
# 1 records were found in the same publication
# (567, 32)
#                                               triple_x  \
# 0    Pesticide Residues:COEXISTS_WITH:Ginseng Prepa...
# 1        Ginsenoside:COEXISTS_WITH:Ginseng Preparation
# 2         Pesticides:COEXISTS_WITH:Ginseng Preparation
# 3     RBL2 gene|RBL2:COEXISTS_WITH:Ginseng Preparation
# 4    NOS2A protein, human|NOS2:INHIBITS:Ginseng Pre...
# ..                                                 ...
# 563  Ginsenosides:AFFECTS:Diabetes Mellitus, Insuli...
# 564  Ginsenosides:AFFECTS:Diabetes Mellitus, Insuli...
# 565                   ursolic acid:INHIBITS:E-Selectin
# 566         panaxadiol:INTERACTS_WITH:STAT3 gene|STAT3
# 567               ginsenoside Rg3:AFFECTS:Osteoporosis
#
#                 subject_name_x subject_type_x   subject_id_x     predicate_x  \
# 0           Pesticide Residues           hops       C0031251   COEXISTS_WITH
# 1                  Ginsenoside           orch       C1165265   COEXISTS_WITH
# 2                   Pesticides           hops       C0031253   COEXISTS_WITH
# 3               RBL2 gene|RBL2           gngm  C1335602|5934   COEXISTS_WITH
# 4    NOS2A protein, human|NOS2           aapp  C0669372|4843        INHIBITS
# ..                         ...            ...            ...             ...
# 563               Ginsenosides           orch       C0061278         AFFECTS
# 564               Ginsenosides           orch       C0061278         AFFECTS
# 565               ursolic acid           orch       C0077938        INHIBITS
# 566                 panaxadiol           orch       C0069999  INTERACTS_WITH
# 567            ginsenoside Rg3           orch       C0385181         AFFECTS
#
#                             object_name_x object_type_x    object_id_x  \
# 0                     Ginseng Preparation          orch       C1119918
# 1                     Ginseng Preparation          orch       C1119918
# 2                     Ginseng Preparation          orch       C1119918
# 3                     Ginseng Preparation          orch       C1119918
# 4                     Ginseng Preparation          orch       C1119918
# ..                                    ...           ...            ...
# 563  Diabetes Mellitus, Insulin-Dependent          dsyn       C0011854
# 564  Diabetes Mellitus, Insulin-Dependent          dsyn       C0011854
# 565                            E-Selectin          gngm       C0115305
# 566                      STAT3 gene|STAT3          aapp  C1367307|6774
# 567                          Osteoporosis          dsyn       C0029456
#
#      localCount_x  localTotal_x  ...  object_type_y  object_id_y  \
# 0               6          4955  ...           dsyn     C0011615
# 1               5          4955  ...           dsyn     C0011615
# 2               4          4955  ...           dsyn     C0011615
# 3               4          4955  ...           dsyn     C0011615
# 4               2          4955  ...           dsyn     C0011615
# ..            ...           ...  ...            ...          ...
# 563             2          4955  ...           dsyn     C0011615
# 564             2          4955  ...           dsyn     C0011615
# 565             2          4955  ...           dsyn     C0011603
# 566             2          4955  ...           dsyn     C0022398
# 567             2          4955  ...           dsyn     C0037274
#
#      localCount_y  localTotal_y globalCount_y globalTotal_y      odds_y  \
# 0               5         24433             5       8040465  329.149337
# 1               5         24433             5       8040465  329.149337
# 2               5         24433             5       8040465  329.149337
# 3               5         24433             5       8040465  329.149337
# 4               5         24433             5       8040465  329.149337
# ..            ...           ...           ...           ...         ...
# 563             4         24433             4       8040465  329.135904
# 564             3         24433             3       8040465  329.122472
# 565             3         24433             3       8040465  329.122472
# 566             4         24433            15       8040465   87.769454
# 567             3         24433             3       8040465  329.122472
#
#            pval_y                              pmids_y       set_y
# 0    1.000000e-10  30187459 29126802 28413317 24269244  dermatitis
# 1    1.000000e-10  30187459 29126802 28413317 24269244  dermatitis
# 2    1.000000e-10  30187459 29126802 28413317 24269244  dermatitis
# 3    1.000000e-10  30187459 29126802 28413317 24269244  dermatitis
# 4    1.000000e-10  30187459 29126802 28413317 24269244  dermatitis
# ..            ...                                  ...         ...
# 563  5.800000e-09                    26370535 11403811  dermatitis
# 564  5.523000e-07                    26253344 24053642  dermatitis
# 565  5.523000e-07             11355655 1708800 1706195  dermatitis
# 566  3.148000e-07           21703716 21300911 18841165  dermatitis
# 567  5.523000e-07                    32635380 32443893  dermatitis
#
# [567 rows x 32 columns]

# %% [markdown]
# Look at the overlapping data in more detail

# %%
overlap_counts = overlap_df.groupby('object_type_x')['object_name_x'].value_counts()
overlap_counts
# Out:
# object_type_x  object_name_x
# aapp           TNF protein, human|TNF                   14
#                Ovalbumin                                 3
#                NF-kappa B                                2
#                Brain-Derived Neurotrophic Factor         1
#                Interleukin-6                             1
#                Nerve Growth Factors|NGF                  1
#                STAT3 gene|STAT3                          1
#                VEGF protein, human|VEGFA                 1
# dsyn           Dermatitis, Atopic                      312
#                Allergic rhinitis NOS                     8
#                Arthritis                                 6
#                Obesity                                   4
#                Kidney Failure, Acute                     3
#                Cardiovascular Diseases                   2
#                Diabetes Mellitus, Insulin-Dependent      2
#                Chronic Obstructive Airway Disease        1
#                Hypertensive disease                      1
#                Osteoporosis                              1
#                Rheumatoid Arthritis                      1
# gngm           cytokine                                 58
#                Interleukin-4                            54
#                TNF protein, human|TNF                   14
#                Interleukin-2                            12
#                NOS2A protein, human|NOS2                 3
#                CAMP                                      2
#                Inflammasomes                             2
#                Brain-Derived Neurotrophic Factor         1
#                E-Selectin                                1
#                Gelatinase A                              1
#                Glucagon                                  1
#                IgG1                                      1
#                Matrix Metalloproteinases                 1
#                NF-kappa B                                1
#                Superoxide Dismutase                      1
# hops           Warfarin                                  9
# horm           Hydrocortisone                            9
# inch           Hydrogen Peroxide                         2
# orch           Ginseng Preparation                      12
#                Ethanol                                   3
#                Polysaccharides                           1
# phsu           Antioxidants                              9
#                Chinese herbs                             4
# Name: object_name_x, dtype: int64

# %% [markdown]
# ### Publicaton data
#
# We can retrive the SemMedDB data for a give PubMed ID

# %%
pmid = '19755659'
pub_df = sentence(pmid)
pub_df
# Out:
#    PREDICATION_ID  SENTENCE_ID      PMID       PREDICATE    SUBJECT_CUI  \
# 0       131291235    124272128  19755659  INTERACTS_WITH            324
# 1       131291271    124272128  19755659  INTERACTS_WITH  C0879389|4292
# 2       131291696    124272130  19755659  INTERACTS_WITH            324
#
#      SUBJECT_NAME SUBJECT_SEMTYPE OBJECT_CUI OBJECT_NAME OBJECT_SEMTYPE  \
# 0             APC            gngm   C0038792    Sulindac           orch
# 1  MLH1 gene|MLH1            gngm   C0038792    Sulindac           orch
# 2             APC            gngm   C0038792    Sulindac           orch
#
#                              SUB_PRED_OBJ TYPE  NUMBER  SENT_START_INDEX  \
# 0             APC:INTERACTS_WITH:Sulindac   ti       1                21
# 1  MLH1 gene|MLH1:INTERACTS_WITH:Sulindac   ti       1                21
# 2             APC:INTERACTS_WITH:Sulindac   ab       2               367
#
#                                             SENTENCE  SENT_END_INDEX  \
# 0  Sulindac effects on inflammation and tumorigen...             126
# 1  Sulindac effects on inflammation and tumorigen...             126
# 2  To further explore intestinal regional respons...             802
#
#         ISSN        DP       EDAT  PYEAR
# 0  1460-2180  2009 Nov  2009-9-17   2009
# 1  1460-2180  2009 Nov  2009-9-17   2009
# 2  1460-2180  2009 Nov  2009-9-17   2009
